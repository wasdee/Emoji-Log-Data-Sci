# %%
from github import Github

# First create a Github instance:

# using an access token
with open('token.txt') as f:
    g = Github(f.read())

# %%
for repo in g.get_user().get_repos():
    print(repo.name)

# %%
repo
# Out:
# Repository(full_name="wasdee/zstd")

# %%
for c in repo.get_commits():
    break
c
# Out:
# Commit(sha="a3481d6de0fe50953dfda6ad4513a141eacd968b")

# %%
c.commit.message
# Out:
# 'make uninstall'

# %%
repo = g.get_repo("ahmadawais/Emoji-Log")

# %%
label_to_commit = {p: list() for p in prefixes}

for repo in g.get_repo("ahmadawais/Emoji-Log").owner.get_repos():
    for c in repo.get_commits():
        commit_msg = c.commit.message
        if ':' in commit_msg:
            prefix, msg = commit_msg.split(':', maxsplit=1)
            prefix = prefix.strip()
            if prefix in prefixes:
                label_to_commit[prefix].append(msg.splitlines()[0].strip())
            else:
                print(f"prefix not match: {commit_msg}")
        else:
            print(f"separator not found: {commit_msg}")
# Out:
# separator not found: Update README.md
# prefix not match: ADD: ReadMe FOSS WPCouple Partners info.
# prefix not match: ADD: ReadMe FOSS WPCouple Partners info.
# separator not found: App Name 💯
# separator not found: Add Google Analytics 💯
# separator not found: Initial commit
# separator not found:  💯
# separator not found:  💯
# separator not found: first commit
# prefix not match: ADD: ReadMe FOSS WPCouple Partners info.
# prefix not match: ADD: ReadMe FOSS WPCouple Partners info.
# separator not found: Initial commit
# prefix not match: ADD: ReadMe FOSS WPCouple Partners info.
# prefix not match: ADD: ReadMe FOSS WPCouple Partners info.
# separator not found: Image Screenshot 💯
# separator not found: App starts fine. 💯
# separator not found: First Commit 💯
# prefix not match: ADD: ReadMe FOSS WPCouple Partners info.
# prefix not match: ADD: ReadMe FOSS WPCouple Partners info.
# separator not found: Welcome Page Added
# separator not found: Refresh the placeholders
# separator not found: Add gitignore
# separator not found: Instructions added
# separator not found: Instructions added
# separator not found: First commit
# separator not found: First commit
# separator not found: First commit
# separator not found: First commit
# separator not found: First commit
# separator not found: Fix typo
# separator not found: Bump version and add/update packages
# separator not found: Update README files
# separator not found: Check if account is verified
# separator not found: Clear 'message sent' state if email changes
# separator not found: Add email body templates
# separator not found: Add buildTemplate()
# separator not found: Implement notistack for alerts
# separator not found: Bump version and update packages
# separator not found: Support APP_AUTH_URL
# separator not found: Add APP_AUTH_URL and improve types
# separator not found: Add JWT to response
# separator not found: Make cookie persistent
# separator not found: Add HTML body to outgoing mail
# separator not found: Fix reCAPTCHA
# separator not found: Bump version and upgrade packages
# separator not found: Remove `PROD` environment variable
# separator not found: Add STATIC_PATH
# separator not found: Update packages
# separator not found: Fix webpack.config.js
# separator not found: Remove unused property
# separator not found: Bump version
# separator not found: Serve static web files from server
# separator not found: Use dotenv
# separator not found: Remove users
# separator not found: Update ignore files
# separator not found: Ignore docker-compose.yml
# separator not found: Update README
# separator not found: Version bump
# separator not found: Add web service
# separator not found: Add web/Dockerfile
# separator not found: Remove unnecessary PATH change
# separator not found: Fix dev server
# separator not found: Use process.enve instead of constants/config
# separator not found: Use enve
# separator not found: Update volumes
# separator not found: Set user to root
# separator not found: Install nodemon locally
# prefix not match: Update server: bash task
# prefix not match: Use node:current-alpine
# separator not found: Replace bcrypt with bcryptjs
# separator not found: Import lib/utils/parse-env
# separator not found: Move 'parse process.env' code into its own file
# separator not found: Add tasks
# separator not found: Fix watch-start script
# prefix not match: Add "Server: Inspect"
# separator not found: Improve watch-start script
# separator not found: Remove WEB_DIRECTORY
# separator not found: Improve Dockerfile
# separator not found: Improve docker-compose.yml
# separator not found: Add watch-start script
# separator not found: Update to ignore .env files
# separator not found: Add docker-compose.yml
# separator not found: Improve docker files
# separator not found: Add Dockerfile for server
# separator not found: Add .dockerignore
# separator not found: Parse environment variables
# separator not found: Add type definitions for environment variable
# separator not found: Use environment variables instead of config file
# separator not found: Set testEnvironment
# separator not found: Fix typo
# separator not found: Rename api/routers
# separator not found: Fix typo
# separator not found: Update README
# separator not found: Bump versions and upgrade packages
# separator not found: Make JWT cookie name configurable
# separator not found: Make JWT lifespans configurable
# separator not found: Set NODE_ENV
# separator not found: Update name and version
# separator not found: Remove unused
# separator not found: Resize images
# separator not found: Improve README
# separator not found: Add .npmignore
# separator not found: Add accownt package
# separator not found: Add description
# separator not found: Add default configs with annotations
# separator not found: Add README files
# separator not found: Add alpha version
# separator not found: Add LICENSE.md
# separator not found: Add 'Back to {NAME}' button
# separator not found: Reset failedLogins after 15 minutes
# separator not found: Handle errors for API routes where user needs to be redirected
# separator not found: Handle competing email verification tokens
# separator not found: Improve search and file exclusion
# separator not found: Send credentials from webpack dev server page to API
# separator not found: Decrease TOTP secret length
# separator not found: Remove Accownt.Account.loggedIn
# separator not found: Remove mailcomposer
# separator not found: Add <Authenticated>
# separator not found: Return setTOTP() return
# separator not found: Add <Unauthenticated>
# separator not found: Add <App>
# separator not found: Fix passing JWT to lib module
# separator not found: Support CORS in development
# separator not found: Remove passwordless boolean so it's always enabled
# prefix not match: Fix passwordless login: accept email instead of user id
# separator not found: Remove redirect
# separator not found: Add constants/theme
# separator not found: Add Accownt.Account type
# separator not found: Add lib/api
# separator not found: Add lib/index
# separator not found: Update for accownt-web
# separator not found: Convert to TypeScript
# separator not found: Update build process
# separator not found: Remove unused
# separator not found: Fix setPassword() test
# separator not found: Fix and improve checkEmail()
# separator not found: Fix and improve emailToId()
# separator not found: Add test scripts and change packages
# separator not found: Add tests with jest
# separator not found: Ignore coverage/
# separator not found: Use emailToId() and cleanEmail()
# separator not found: Make pass optional
# separator not found: Remove default `digits`
# separator not found: Add emailToId()
# separator not found: Split verifyJWT()
# separator not found: Make reCAPTCHA optional
# separator not found: Return generated token for testing
# separator not found: Update sendMail() to use nodemailer w/ SMTP transport
# separator not found: Add middleware to log and output errors from API controllers
# separator not found: Remove oldPass check
# separator not found: Update API route and controller system
# separator not found: Change email verification URL
# separator not found: Save generated totpSecret
# separator not found: controllers/ -> api/
# separator not found: Add setTOTP() and API
# separator not found: Add setPasswordless() and API
# separator not found: Update getAccount() location and its return
# separator not found: Add finishRegistration() and API
# separator not found: Add startRegistration() and API
# separator not found: Add cleanEmail()
# separator not found: Make oldPass optional
# separator not found: Add checkEmail() and API
# separator not found: Remove account recovery since passwordless login serves its purpose
# separator not found: Add login() and API
# separator not found: Update logout()
# separator not found: Improve how JWTs are handled
# separator not found: Move 'clean email' module into 'create account'
# separator not found: Add verifyPasswordlessLogin() and API
# separator not found: Move JWT interface to types/
# separator not found: Add sendPasswordlessLoginEmail() and API controller
# separator not found: Fix
# separator not found: Remove unused
# separator not found: Add 'set password' modules
# separator not found: Add 'get account from session' modules
# separator not found: Remove unused
# separator not found: Rename and move controllers
# separator not found: Add types
# separator not found: Update code to TypeScript
# separator not found: Add type definitions
# separator not found: Add TypeScript
# separator not found: Change .js -> .ts
# separator not found: Move App.html
# separator not found: Remove randomstring
# separator not found: Remove .vscode/ from .gitignore
# separator not found: Split into server and web
# separator not found: Begin converting to Accownt
# separator not found: Remove unused
# separator not found: Add middleware/jwt
# separator not found: Remove unused
# separator not found: Remove unused
# separator not found: Update babel
# separator not found: Remove rword
# separator not found: Clean up code
# separator not found: Remove developer dashboard
# separator not found: Remove Redirect.html
# separator not found: Remove admyn
# separator not found: Add server/
# separator not found: Rename client/ -> web/
# separator not found: Fix
# separator not found: Fix
# separator not found: Version bump. Update, remove packages
# separator not found: Fix redirect
# separator not found: Remove `md-cell` class
# separator not found: Remove security codes
# separator not found: Remove recovery code options
# separator not found: Remove security codes
# separator not found: Listen for Enter key for form submit
# separator not found: Remove deprecated
# separator not found: Remove unused
# separator not found: Remove deprecated routes
# separator not found: Updates for React 16.3+
# separator not found: Fix path
# separator not found: Remove edit link
# separator not found: Fix import
# separator not found: Remove unused code
# separator not found: Remove unused
# separator not found: Update URL routes
# separator not found: Updates and improvements
#
# - Remove deprecated route
# - Update code style
# - Improve code
#  - Only return `email` / `message` / `accessToken`
# prefix not match: Remove `PUT /api/dashboard/user/services/:service`
# separator not found: Remove service 'info'
# separator not found: Remove deprecated route
# separator not found: Replace lib/db with lib/mysql
# separator not found: Updates and improvements
# separator not found: Remove affiliate system
# separator not found: Fix logout
# separator not found: Remove affiliate system
# separator not found: Fix / improve
# separator not found: Doc updates
# separator not found: Redirect from hash to normal routes
# separator not found: Replace hash routes with normal routes
# separator not found: URL updates
# separator not found: URL route updates
# prefix not match: Remove `error: boolean` from responses and return `400` status instead
# separator not found: Use location.replace
# separator not found: Version bump. Update packages
# separator not found: Version bump. Updates
# separator not found: Fix / clean up code
# separator not found: Fix / clean up code
# separator not found: Version bump. Add prettier. Update packages
# separator not found: Updates. Target latest browsers
# separator not found: Support passing `email` query string variable to login
# prefix not match: Add `POST /api/service/:service/verified`
# separator not found: Long polling for checking auth id
# separator not found: Allow users without passwords to set a password
# separator not found: Make password optional
# separator not found: Prevent multiple submissions
# separator not found: If password is blank for login, send login link
# separator not found: Make password optional
# separator not found: Improvements
# separator not found: Updates and improvements
# separator not found: Format code with prettier
# separator not found: Version bump. Update, remove packages
# separator not found: Add jobs/remove-profiles
# separator not found: Add middleware/clean-email
# separator not found: Remove profiles
# separator not found: Remove gulp
# separator not found: Remove fontello
# separator not found: Upgrade webpack
# separator not found: Version bump. Update packages
# separator not found: Improve login links
# separator not found: Fix router
# separator not found: Fix rendering on FireFox
# separator not found: Add `content-type` meta
# separator not found: Version bump. Update, remove packages
# separator not found: Improve footer/Navigation
# separator not found: Improve login page
# separator not found: Remove Google Sign-In support
# separator not found: Version bump. Update package
# separator not found: Apple reviewers are idiots
# separator not found: Version bump. Update packages
# separator not found: Rename / update `lib/url/parse-hash-query`
# separator not found: Version bump
# separator not found: Remove logout button
# prefix not match: Rename `css:main` -> `css:app`
# separator not found: Greatly simplify Home
# separator not found: Improve the Drawer's navItems
# separator not found: Style fixes
# separator not found: Improvements
# separator not found: Version bump. Update packages
# separator not found: Fixes
# separator not found: Split Navigation/Alert from App
# separator not found: Improve `.md-paper.section`
# separator not found: `style.css` -> `styles.scss`
# separator not found: Add `jobs/google`
# separator not found: Move cron jobs
# separator not found: Prepare to remove Google Sign-In support
# separator not found: Let Google users set their password
# separator not found: Allow Google users to set password. Update code style
# separator not found: Disable creating accounts with Google
# separator not found: Fix issuer not showing in Authy
# separator not found: Version bump. Update packages
# separator not found: Auto link if service is only requesting required email
# separator not found: Version bump. Add, update packages
# separator not found: Support Admyn
# separator not found: Add Admyn admin panel
# separator not found: Fixes / updates
# separator not found: Style updates for (link|updated-linked)-service sections
# separator not found: UI / UX / code improvements
# separator not found: Return user's account email
# separator not found: Version bump. Add package
# separator not found: Add production plugins
# separator not found: Improvements
# separator not found: Enable passwordless login by default
# separator not found: Version bump. Add package
# separator not found: Improvements, changes
#
# - Integrate `loginWithAuthId()`.
# - Code improvements
# - Remove `onLogin()` and 'Authorization Code' input
# separator not found: Integrate `loginWithAuthId()`. Code / output improvements
# separator not found: Add `client/lib/account/login-with-auth-id`
# separator not found: Add `POST api/login/auth-id` controller
# separator not found: Improvements, changes
#
# - Update code style
# - Use lib/mysql
# - Update `validateToken()` usage
# separator not found: Update `generateToken()` usage
# separator not found: Improvements, changes
#
# - Update code style
# - Use lib/mysql
# - Update `generateToken()` usage
# - Modify return
# - Modify route
# separator not found: Update `generateToken()` usage
# separator not found: Return `authId`, `userId`
# separator not found: Improve message
# separator not found: Update `generateToken()` usage
# separator not found: Improve message. Return `auth_id`
# separator not found: Improvements, changes
#
# - Improved code and docs
# - Remove `fn` callback
# - Support `security.auth_verified` and `security.auth_id`
# - Modify return in certain instances
# separator not found: Improvements, changes
#
# - Improved code and docs
# - Remove `fn` callback
# - Support `security.auth_verified`
# separator not found: Update `lib/email/send` usage
# separator not found: Improvements
#
# - Update code style
# - Add JSDOC
# - Change accepted params
# - Return promise / response
# separator not found: Disable `sha512` for TOTP
# separator not found: Fix css task
# separator not found: Version bump. Update packages
# separator not found: Improvements
#
# - Improved error checking
# - Pass `serviceName`, `serviceUrl` query string variables to `#/login`
# - Call `_createSession()` if service is already linked
# separator not found: Improvements
#
# - Remove unused `state.message`
# - Improve error checking
# - Pass `serviceName`, `serviceUrl` to `#/login`
# separator not found: UI / UX improvements
#
# - Accept / pass `email` query string variable from / to other components
# - Improve login attempts code / wording
# - Support `serviceName` and `serviceUrl` query string variables
# separator not found: UI / UX improvements
# separator not found: Accept `email` query string variable
# separator not found: Update code style
# separator not found: Improvements
#
# - Always return `service`
# - Return more data in `service`
# - Improve documentation
# - Improve / clean up code
# separator not found: Version bump. Add, remove packages
# separator not found: Use webpack for building JS
# separator not found: Version bump. Update, remove packages
# separator not found: Improvements
# separator not found: Fix Dialog's onHide
# separator not found: `profile_id` -> `id`
# separator not found: Improvements, changes
#
# - Use lib/mysql
# - Update code style
# - `profile_id` -> `id`
# - Improve output
# separator not found: Update SweetAlert usage
# separator not found: Update code style. Use `setInterval` instead of `cron`
# separator not found: Improve profiles system
#
# - Remove .old
# - Use react-md
# - Update code style
# - Split components / routes
# separator not found: Use react-md
# separator not found: Use react-md
# separator not found: Improve routes. Remove .old
# separator not found: Remove old affiliate, profiles, and services tyles
# separator not found: Remove .old
# separator not found: Force floating labels always
# separator not found: Version bump. Update packages
# separator not found: Support Authy
# separator not found: Increase 'Used For' description length
# separator not found: OTP fixes and improvements
# separator not found: Add, update, remove packages
# separator not found: Rename AppOTP -> OTP
# separator not found: Remove SMS 2FA and SMS passwordless login
# separator not found: Updates / improvements
# separator not found: Update react-md to v1.1.x
# separator not found: Change how SweetAlert is imported
# separator not found: Update SweetAlert to v2
# separator not found: Remove client/lib/request
# separator not found: Improvements
#
# - Update code style
# - Use SweetAlert v2
# - Replace lib/request with superagent
# separator not found: Update packages
# separator not found: Update 'Advertise' link
# separator not found: Remove anything related to Xyfir Ads v1
# separator not found: Update, remove packages
# separator not found: Use react-md components. Improve wording
# separator not found: Remove home styling
# separator not found: Increase token / key length
# separator not found: Changes to #/dashboard/user/tokens styling
# separator not found: Improvements, changes
#
# - Use react-md components
# - Support 'delete all tokens' feature
# - Support naming tokens
# separator not found: Add controller for PUT api/dashboard/user/tokens
# separator not found: Improvements, changes
#
# - Update code style
# - Use lib/mysql
# - Support deleting all tokens
# separator not found: Support recovery code
# separator not found: Support recovery code to bypass 2FA
# separator not found: Add RecoveryCode component
# separator not found: Add, change routes/controllers
# separator not found: Add controller for PUT api/dashboard/user/security/recovery-code
# separator not found: Add controller for GET api/dashboard/user/security/recovery-code
# separator not found: Rename / move down to phone/
# separator not found: Update, add packages
# separator not found: Add `google` to return object
# separator not found: Hide if props.google is true
# separator not found: Change secondary color
# separator not found: Support app 2fa otp
# separator not found: Update docs
# separator not found: Improve docs. Support otp_secret. Update lib/security/initiate
# separator not found: Support otp_secret
# separator not found: Use JSDOC. Support otp_secret
# separator not found: Change code style. Use JSDOC
# separator not found: Clear otp_secret when saving phone
# separator not found: Add .security styling
# separator not found: Add controller for PUT api/dashboard/user/security/otp
# separator not found: Add SetAppOTP component
# separator not found: Split <Security> into multiple components
# separator not found: Improve output. Add `appOtp` to output object
# separator not found: Fix hiding current password input after recovery
# separator not found: Update code / style
# separator not found: Use react-md components. Improve code / UI
# separator not found: Improvements, changes
#
# - Update code style
# - Use lib/mysql
# - Use JSDOC
# separator not found: Improvements, changes
#
# - Update code style
# - Use lib/mysql
# - Improve docs
# - Use new lib/security/validate
# separator not found: Improvements, changes
#
# - Update code style
# - Use lib/mysql
# - Set phone number after being verified
# separator not found: Improvements, changes
#
# - Update code style
# - Use lib/mysql
# - Improve output
# - Do not set phone until verified unless the phone is being removed
# separator not found: Improvements, changes
#
# - Update code style
# - Use lib/mysql
# - Use JSDOC
# - Remove callback, make async
# separator not found: Improvements, changes
#
# - Update code style
# - Add JSDOC documentation
# - Use lib/mysql
# - Change SQL query
# separator not found: Pass all props to children
# separator not found: Add alerts using react-md's <Snackbar>
# separator not found: Add jsconfig.json files
# separator not found: Add google-auth-library
# separator not found: Add 'Google Login' button
# separator not found: Improvements, changes
#
# - Use react-md components
# - Hide 'change password' section if user logs into account via Google
# separator not found: Improvements, changes
#
# - Update code style
# - Use lib/mysql
# - Return `google` boolean
# separator not found: Add 'Google Login' button
# separator not found: Import Google API
# separator not found: Add controller for POST api/login/google
# separator not found: Move a portion of code into lib/users/create
# separator not found: Add / change routes / controllers
# separator not found: Remove old / unused code
# separator not found: Use config.addresses.xacc for link
# separator not found: Improvements, changes
#
# - Change code style
# - Use lib/mysql
# - Update 'service login' route
# separator not found: Update 'register service' route
# separator not found: Improvements, changes
#
# - Change code style
# - Use superagent
# - Use lib/mysql
# prefix not match: Improvements, changes
#
# - Accept email as query variable instead of parameter
# - Use lib/mysql
# - Change code style
# - Modify output to { exists: boolean }
# separator not found: Remove outdated / unused styles
# separator not found: Change LinkService container to RegisterService component
# separator not found: Remove step-form.scss
# separator not found: Improvements, changes
#
# - Move components/containers/Register code to components/register/Account
# - Modify Register container to handle #/register routes
# - Update RegisterAccount code style / use superagent / react-md
# separator not found: Changes to #/register routes
# prefix not match: Move into components/login. Support #/login/service/:id route
# separator not found: Move to #/login/recovery. Update code. Use react-md
# separator not found: Update code. Improve email
# separator not found: Add PasswordlessLogin
# separator not found: Add LoginStep2
# separator not found: Add LoginStep1
# separator not found: Modify to handle #/login routes
# separator not found: Remove 'login step' components
# separator not found: Route / component changes
# separator not found: Change code style. Improve email
# separator not found: Improvements and fixes
# separator not found: Improvements
#
# - Change code style
# - Add JSDOC documentation
# - Improve email
# separator not found: Rename folder to 'profiles' (lowercase)
# separator not found: Update imports
# separator not found: Add, remove packages
# separator not found: Improvements, changes
#
# - Change code style
# - Use lib/mysql
# - Notify service if url_update is present
# separator not found: Improvements, changes
#
# - Change code style
# - Use lib/mysql
# - Notify service if url_unlink is present
# separator not found: Change button label
# separator not found: Add lib/service/get-linked-profile
# separator not found: Change .dashboard-developer styles. Clean up code
# prefix not match: Add text-align: left for .md-text-field-container
# separator not found: Improvements, changes
#
# - Change code style
# - Add JSDOC documentation
# - Remove validator
# - Support new properties
# separator not found: Improvements, changes
#
# - Change code style
# - Rename to build-info
# - Add JSDOC documentation
# separator not found: Improvements, changes
#
# - Change code style
# - Use lib/mysql
# - Update validate() usage
# - Update buildInfo()'s import path
# separator not found: Improvements, changes
#
# - Change code style
# - Use lib/mysql
# - Update validate() usage
# - Update buildInfo()'s import path
# separator not found: Add .flex
# separator not found: Improvements, changes
#
# - Change code style
# - Use superagent
# separator not found: Improvements, changes
#
# - Change code style
# - Update <Form> usage
# separator not found: Improvements, changes
#
# - Change code style
# - Update <Form> usage
# separator not found: Improvements, changes
#
# - Change code style
# - Use superagent
# - Use react-md components
# separator not found: Improvements, changes
#
# - Update code style
# - Use superagent
# - Use react-md components
# separator not found: Improvements, changes
#
# - Update code style
# - Use superagent
# - Use react-md components
# separator not found: Improvements, changes
#
# - Update code style
# - Use superagent
# - Use react-md components
# separator not found: Add nav.navbar-sub styles
# separator not found: Improvements, changes
#
# - Change code style
# - Use superagent
# - Update _createSession() to reflect API changes
# - Update output
# separator not found: Remove dev / testing code
# separator not found: Improvements, changes
#
# - Change code style
# - Use lib/mysql
# - Replace address column with url_main
# separator not found: Replace address column with url_main
# separator not found: Return redirect url. Replace address with url_login
# separator not found: Update _createSession() to reflect API changes
# separator not found: Add .old to components that need to be updated
# separator not found: Rename components/dashboard/user/profiles
# separator not found: Update, add, remove packages
# separator not found: Add div.update-linked-service
# separator not found: Update api urls
# separator not found: Add ViewLinkedService
# separator not found: Add ListLinkedServices
# separator not found: Modify service components to be different view
# separator not found: Improvements, changes
#
# - Change code style
# - Use lib/mysql
# - Use async / await
# - Return address and description
# separator not found: Add new div.link-service styling
# separator not found: Update styling to work with react-md
# separator not found: Improvements and implement react-md components
#
# - Use react-md components
# - Use country-region-data for country / region selectors
# - Hide disabled elements in custom tab
# - Clean up code
# separator not found: Make <Toolbar> fixed
# separator not found: Set NODE_ENV. Only run uglify in prod
# separator not found: Clean up code
# separator not found: Improvements, updates
#
# - Use twilio v3
# - Change code style
# - Add JSDOC documentation
# - Use async / await
# separator not found: Hide drawer by default. Clean up code
# separator not found: Add redirect from /app route to /
# prefix not match: Remove certain :focus styles
# separator not found: Check login status in UserDashboard
# separator not found: Remove /app/ route
# separator not found: Remove /app/ route. Change code style
# separator not found: Remove /app route. Change code style
# separator not found: Support Home component. Remove DynamicStyles
# separator not found: Replace Home.html with Home component
# separator not found: Add and remove packages
# separator not found: Add react-md Toolbar / Drawer. Change code style
# separator not found: Remove header. Change font. Add Material icons
# separator not found: Improvements, changes
#
# - Change code style
# - Switch font-family to Roboto
# - Remove styling (header, nav, misc)
# - Improve styling
# separator not found: Improvements, changes
#
# - Change code style
# - Use superagent
# - Remove nav
# separator not found: Add react-md.scss
# separator not found: Improvements, changes
#
# - Change code style
# - Replace postcss / plugins with gulp-sass
# separator not found: Fix class prop. Change code style
# separator not found: Fix callback / return being missed
# separator not found: Add metadata. Improve wording / misc
# separator not found: Update / add packages
# separator not found: Route changes
# separator not found: Improvements, changes
#
# - Change code style
# - Use lib/mysql
# - Use async / await
# separator not found: Improvements, changes
#
# - Change / add API route(s)
# - Change code style
# - Use lib/mysql
# - Use async / await
# separator not found: Improvements, changes
#
# - Change code style
# - Use lib/mysql
# - Use async / await
# - Add JSDOC docs
# separator not found: Improvements, changes
#
# - Change code style
# - Use lib/mysql
# - Use async / await
# - Add JSDOC docs
# separator not found: Replace validateData with validate-data
#
# - Change code style
# - Use async / await
# - Use lib/mysql
# - Add JSDOC documentation
# separator not found: Fixes, improvements
#
# - Change code style
# - Use superagent
# - Fix updating when in 'custom' tab
# separator not found: Change API routes
# separator not found: Increase size limit for body-parser. Change code style
# separator not found: Support profile pictures. Add JSDOC documentation
# separator not found: Add profile image styling. Change code style
# separator not found: Improvements, changes
#
# - Change code style
# - Use superagent
# - Reload page to update list
# separator not found: Improvements, changes
#
# - Change code style
# - Use async / await
# - Use lib/mysql
# - Update profile validation
# separator not found: Improve profile validation
#
# - Change code style
# - Add JDSOC documentation
# - FIx email validation
# - Remove some validation
# - Rename to validate
# - Modify to simply throw error when data is invalid
# separator not found: Use superagent. Change code style
# separator not found: Remove IP whitelist route. Change code style
# separator not found: Improvements, changes
#
# - Change code style
# - Clean up code
# - Use lib/mysql
# - Use async/await
# separator not found: Improvements, changes
#
# - Change code style
# - Clean up code
# - Use lib/mysql
# - Use async/await
# separator not found: Improvements, changes
#
# - Change code style
# - Clean up code
# - Use lib/mysql
# - Use async/await and promises
# - Update rword
# separator not found: Improvements
#
# - Change code style
# - Clean up code
# - Use lib/mysql
# - Use async/await and promises
# separator not found: Improvements, changes
#
# - Change code style
# - Clean up code
# - Use superagent
# - Remove IP address whitelist feature
# - Add 'Reset Codes' button
# - Improve security codes output
# separator not found: Improvements, changes
#
# - Change code style
# - Clean up code
# - Use superagent
# - Remove passworld length requirement
# separator not found: Improvements
#
# - Change code style
# - Clean up code
# - Use superagent
# separator not found: Remove IP address whitelist feature
# separator not found: Improvements
#
# - Use lib/mysql
# - Use async and await
# - Change code style
# separator not found: Improvements
#
# - Use lib/mysql
# - Use async and await
# - Change code style
# separator not found: Change name and code style
# separator not found: Add lib/mysql
# separator not found: Update packages
# separator not found: Use superagent. Fix errors.
# separator not found: Redirect when not logged in. Change code style
# separator not found: Update packages. Add superagent
# separator not found: Fix variable result -> res
# separator not found: Update packages
# separator not found: Fix link regex
# separator not found: Add rword. Update packages
# separator not found: Use rword package instead of API. Clean up code
# separator not found: Update packages
# separator not found: Increase access token life to one week
# separator not found: Add link to service's site. Clean up code
# separator not found: Add service address to return. Clean up code.
# separator not found: Add link icon
# separator not found: Re-add _updateProfiles()
# separator not found: Add 'Create New Profile' link
# separator not found: Use <section>. Support redirect custom redirect
# separator not found: Add url/parse-hash-query module
# separator not found: Split Profiles into ProfileList and CreateProfile
# separator not found: Add component to manage profiles routes
# separator not found: Move down into Profiles/. Change birthdate input type
# separator not found: Disable inputs for fields that service won't accept
# separator not found: Clean up code and output. Add 'Continue to Login' button on success
# separator not found: Add styling for disabled inputs
# separator not found: Improve email message
# separator not found: Support sending HTML
# separator not found: Add mailcomposer. Update packages
# separator not found: Fix undefined variable error cause by tabs
# separator not found: Update packages
# separator not found: Use forms. Default dataTab to custom if no profiles available
# separator not found: Clean up code. Only return message on error
# separator not found: Clean up code. Add error checking for SQL query
# separator not found: Improve styling. Add proper sticky footer
# separator not found: Add viewport meta. Improve output / navbar
# separator not found: Remove #content margin-bottom
# separator not found: Improve output
# separator not found: Update and improve code
# separator not found: On success delete unverified accounts with same email
# separator not found: Remove password input description
# separator not found: Remove doLogin. Update sendVerificationEmail path
# separator not found: Rename to send-verification.js
# separator not found: Remove doLogin
# separator not found: Update dashboard redirect link
# separator not found: Use <section>. Improve output / styling
# separator not found: Move navbar into UserDashboard
# separator not found: Remove .dashboard-.nav
# separator not found: Add POST api/affiliate/signup controller
# separator not found: Add POST api/affiliate/purchase controller
# separator not found: Add /affiliate routes/controllers
# separator not found: Change route for loading promotions
# separator not found: Add promotion link
# separator not found: Move to controllers/affiliate
# separator not found: Add .dashboard-affiliate styling
# separator not found: Add ListAffiliateCampaigns component
# separator not found: Add CreateAffiliateCampaign component
# separator not found: Output navbar and children components
# separator not found: Add affiliate dashboard routes/controllers
# separator not found: Add POST api/dashboard/affiliate controller
# prefix not match: Add DELETE api/dashboard/affiliate/:code controller
# separator not found: Add GET api/dashboard/affiliate/promotions controller
# separator not found: Add GET api/dashboard/affiliate controller
# separator not found: Fix setting location.hash
# separator not found: Return affiliate boolean
# separator not found: Change / add dashboard links / name
# separator not found: Move table.requested-info|data
# separator not found: Pass children hash property
# separator not found: Move into specific dashboard folder. Fix import paths
# separator not found: Update API / hash routes
# separator not found: Change dashboard/* and service/dashboard/* routes
# separator not found: Clean up code
# separator not found: Add AffiliateDashboard component
# separator not found: Move into dashboard/developer. Use SweetAlert
# separator not found: Move into dashboard/user. Use SweetAlert
# separator not found: Move user dashboard container to components/dashboard/user. Support multiple dashboards
# separator not found: Remove <Service>
# separator not found: Update packages
# separator not found: Improve code and output
# separator not found: dashboard.scss -> misc.scss
# separator not found: Improve return for optional information
# separator not found: Pass redirect value to _login() in onNext()
# separator not found: Rename to misc.scss. Improve styling
# separator not found: Remove progress bar styling
# separator not found: Update packages
# separator not found: Replace <Alert> with SweetAlert. Add unlink confirmation
# separator not found: Add confirmation popup when deleting profile
# separator not found: Replace <Alert> with SweetAlert
# separator not found: Add 'create profile' route
# separator not found: Disallow deleting profiles linked to services
# separator not found: Link SweetAlert css/js
# separator not found: Add copy-libs, copy-css
# separator not found: Add sweetalert
# separator not found: Fix setting className
# separator not found: Add nav and footer borders
# separator not found: Fix forms. Clean up code
# separator not found: Fixes and improvements
# separator not found: Fix form
# separator not found: Improve styling
# separator not found: Improve nav styling
# separator not found: Return object property 'type' -> 'passwordless'
# separator not found: Fix security code check
# separator not found: Clean up code / improve output. Support passwordless login code
# separator not found: Clean up code / improve output
# separator not found: Rename. Modify to send link and authorization code
# separator not found: Modify to send link and authorization code
# separator not found: Clean up code. Improve security code checks
# separator not found: Clean up / update code
# separator not found: Return passwordless. Update usage of sendPasswordless* functions
# separator not found: Increase input width
# separator not found: Use labels instead of placeholders
# separator not found: Remove 'Both' option for passwordless login
# separator not found: Explain access tokens
# separator not found: Redirect to login if not logged in
# separator not found: Update packages
# separator not found: Update cron
# separator not found: Remove grid
# separator not found: Put navbar links in <div>. Add dynamic styling script
# separator not found: Implement <DynamicStyles />
# separator not found: Generate dynamic CSS styles
# separator not found: Put navbar links in <div>. Move App.js script
# separator not found: Convert to SASS
# separator not found: Modify main navbar
# separator not found: Remove margin-top for navbars
# separator not found: Clean up links
# separator not found: Clean up code
# prefix not match: Give header nav z-index: 2
# separator not found: Improve footer / header styling
# separator not found: Add nav margin-top
# separator not found: Improve header and footer. Remove #container
# separator not found: Fix import paths
# separator not found: Clean up code. Rename
# separator not found: Clean up code
# separator not found: Improve code. Modify sms code to be single 6 digit number
# separator not found: Change selector
# separator not found: Change input type to number
# separator not found: Add random integer generator
# separator not found: Clean up code. Support new generateToken()
# separator not found: Clean up code. Support new validateToken()
# separator not found: Add 'delete expired access tokens' cron job
# separator not found: Run cron jobs
# separator not found: Add cron
# separator not found: Add AccessTokens component
# separator not found: Add controller for DELETE api/dashboard/tokens
# separator not found: Add .dashboard-tokens styling
# separator not found: Add controller for GET api/dashboard/tokens
# separator not found: Clean up code. Modify to support access tokens
# separator not found: Support new generateToken()
# separator not found: Move to lib/tokens. Modify to validate auth or access tokens
# separator not found: Move to lib/tokens. Modify to generate access or auth tokens
# separator not found: Add dashboard/tokens controllers
# separator not found: Remove this.state.view
# separator not found: Add support for #/dashboard/tokens
# separator not found: Add 'Tokens' link
# separator not found: Clean up code. Return service name with id
# separator not found: Clean up code. Add paths[] to browserify()
# separator not found: Clean up code. Token now starts with '1' and is 64 characters long
# separator not found: Add app-module-path
# separator not found: Update packages. Add app-module-path
# separator not found: Support multiple service keys
# separator not found: Remove service_key column/value
# separator not found: Check against multiple service keys
# separator not found: .service-view styling
# prefix not match: Add controller for DELETE api/service/dashboard/:id/key
# separator not found: Add new key instead of replacing existing
# separator not found: Support returning multiple service keys
# separator not found: Change / add controllers
# separator not found: Add icons
# separator not found: Import Alert
# separator not found: Remove <hr />
# separator not found: Improve styling for dashboard
# separator not found: Clean up code / output
# separator not found: Clean up / improve output
# separator not found: Clean up / improve output
# separator not found: Improve 'create profile' output
# separator not found: Clean up output / change classes
# separator not found: Change component classes
# separator not found: Update component classes
# separator not found: Add link to dashboard
# separator not found: Add fontello css
# separator not found: Update Nav component usage
# separator not found: Modify Nav to be entire navbar component
# separator not found: Update packages. Add gulp-fontello
# separator not found: Add fontello task
# separator not found: Add edit, delete, close
# separator not found: Change || to &&
# separator not found: Use validator.isURL() to validate link
# separator not found: Add validator
# separator not found: Redirect to #/login if not logged in
# separator not found: Output loggedIn property
# separator not found: Fix calling _createSession(). Check if user is logged in
# separator not found: Reset session.redirect on successful login
# separator not found: Check if user is logged in
# separator not found: Fix update property for <Server />
# separator not found: Clean up .logo styling
# separator not found: Make logo a link
# separator not found: config.session.secret -> config.keys.session
# separator not found: No longer gzips files in prod env
# separator not found: Clean up / update code
# separator not found: Update packages
# separator not found: Redirect to home page if unknown hash
# separator not found: Remove console.log
# separator not found: Notify user of remaining login attempts
# separator not found: Limit login attempts for incorrect passwords
# separator not found: Ignore .vscode/
# separator not found: Add styling for registration page
# separator not found: XADS-ID generation fix. Implement recaptcha
# separator not found: Merge individual registration steps into single file. Implement recaptcha
# separator not found: Static files now served from static folder/route
# separator not found: Change randword usage
# separator not found: Add favicons. Fix footer links. Use static/ route for public files
# separator not found: mail.xyfir.com -> xyfir.com
# separator not found: Move randword / xads addresses into config.addresses
# separator not found: Update code
# separator not found: Switch from nodemailer to mailgun
# separator not found: Replace nodemailer with mailgun-js
# separator not found: Remove .footer width
# separator not found: this.state.service -> this.state.id
# prefix not match: .post -> .get for /service/:service
# separator not found: Move /service/dashboard routes above normal service routes to prevent wrong controller from being called
# separator not found: Generate service key
# separator not found: Change / add routes / controllers for service key
# prefix not match: Add controller for PUT api/service/dashboard/:id/key
# prefix not match: Add cursor: pointer to a {...}
# separator not found: Add .service-key
# separator not found: Show service key / service id. Add onGenerateKey()
# separator not found: Install randomstring
# separator not found: Clean up code. Implement service key check to increase securirty
# separator not found: p -> key
# separator not found: Define view. Add break; to "delete" case in switch()
# separator not found: Change alert / button types
# separator not found: Use module.exports instead of export default
# separator not found: Update code / update links
# separator not found: Fix passwordless login link
# separator not found: Pass FinalStep this.state.user
# separator not found: Add state.loading. Fix login link
# separator not found: Fix calling onNextStep()
# separator not found: Fix 'create account' and 'account recovery' links
# separator not found: Remove progress bar
# prefix not match: Redirect user instead of returning { error: ... }
# separator not found: Fix logout link
# separator not found: Import Service component. Fix state.services.map
# separator not found: Import Profile component
# separator not found: " -> ' in JSX
# separator not found: Use () => for window.onhashchange so 'this' doesn't change
# separator not found: connection -> cn
# separator not found: Start all routes with /
# separator not found: Fix setting button type
# separator not found: Fix syntax and import path errors
# separator not found: Fix constructor
# separator not found: Cleanup / fix request({...})
# separator not found: Pass <Manage /> props.hash
# separator not found: Update / clean up code
# separator not found: Update / clean up code
# separator not found: Update code to ES6. Improve / use modules
# separator not found: Update code to ES6
# separator not found: Upgrade code to ES6
# separator not found: Update code to ES6
# separator not found: Modify to be child component of App.jsx. Update code to ES6 and to use hash route system
# separator not found: Update to ES6. Modify onClick to set location.hash
# separator not found: Modify to be a child component of App.jsx. Update code to ES6
# separator not found: Add main App container component
# separator not found: Move to containers/
# separator not found: Remove old code from remove  profile controller
# separator not found: check-mail.js -> check-email.js
# separator not found: .del -> .delete
# separator not found: Remove setting view engine. Clean up routes / controllers
# separator not found: Add routes/controllers
# separator not found: Change description
# separator not found: Rename to step-1/step-2
# separator not found: Move into passwordless/ and rename
# prefix not match: Add controller for GET api/recover/:uid/:auth
# separator not found: Rename to step-1/step-2
# separator not found: Add controller for GET api/login/logout
# prefix not match: Add controller for GET api/login/verify-email/:uid/:auth
# prefix not match: Add controller for GET api/login/passwordless/:uid/:auth
# separator not found: Rename to send-passwordless. Add DESCRIPTION
# separator not found: Move from service-dashboard -> service/dashboard
# separator not found: Split service-dashboard.js into individual modules
# separator not found: Split service.js into individual modules
# separator not found: Split register.js into individual modules
# separator not found: Split recover.js into individual controllers
# separator not found: Split login.js into individual modules
# separator not found: Split services.js into individual modules
# separator not found: Split security.js into individual modules
# separator not found: Split profiles.js into individual modules
# separator not found: Split ads.js into info/update
# separator not found: Split account.js into info/update
# separator not found: Remove / clean up routes
# separator not found: Update / add / remove packages
# separator not found: JADE -> HTML
# separator not found: Use color variables from constants.scss
# separator not found: $danger -> $red. Add $orange
# separator not found: Update / improve tasks
# separator not found: Clean up app.js
# separator not found: Add request module
# separator not found: Add workspace settings for vscode
# separator not found: CSS -> SCSS
# separator not found: Move into client/styles
# separator not found: Move into client/components
# separator not found: Rename components/ -> client/
# separator not found: Ignore public/
# separator not found: Modified getUser() to return xad_id on each successful request. Added info comments for all controllers.
# separator not found: Replaced postMessage() with location.href redirect.
# separator not found: Removed unused route/controller.
# separator not found: #content width 80%
# separator not found: Route modification.
# separator not found: Added simple routing to dashboard components.
# separator not found: Replaced session-file-store with a MySQL store.
# separator not found: Improved styling for home page.
# prefix not match: Modified create(): service is Xyfir-owned if uid is less than 1000.
# ...
# value of the `children` property instead of wrapping it with an array.
# This matches the behavior of `React.createElement`.
# separator not found: add undeclared type variable
# separator not found: Merge branch 'master' into development
# separator not found: add optional context parameter to NodePath#get
# separator not found: add more comments to path methods
# separator not found: Merge pull request #1900 from samccone/sjs/opt2
#
# rework findCommonStringDelimiter
# separator not found: Merge pull request #1901 from loganfsmyth/constructor-scope-fix
#
# Properly regenerate scope for replaced nodes - fixes #1773
# prefix not match: :golf:
# separator not found: Properly regenerate scope for replaced nodes - fixes #1773
# prefix not match: Move :white_check_mark: into for block
#
# https://www.youtube.com/watch?v=FHDwRECFL8M
# prefix not match: :fork_and_knife: Switch to ternary for return
#
# https://www.youtube.com/watch?v=XAbY2cmEsS0
# separator not found: Merge pull request #1894 from samccone/patch-4
#
# 🐳
# separator not found: Merge pull request #1895 from samccone/patch-5
#
# remove 💀 comment lines
# separator not found: Merge pull request #1893 from samccone/patch-1
#
# 🍕 Fix grammatical issue
# prefix not match: remove :skull: comment lines
#
# Added in
# https://github.com/babel/babel/commit/3561efdb8682b561052a23c5c9c869e59311ea01
#
# if this is a style thing you want to keep around then my all means close away.
# prefix not match: :baby:
# prefix not match: :lipstick: Fix grammatical issue
# prefix not match: Merge pull request #1892 from samccone/patch-1
#
# :memo: better english
# prefix not match: :memo: better english
# separator not found: Merge pull request #1891 from samccone/patch-1
#
# ⛲️  this that this
# prefix not match: :memo: clarify how it inherits this
# separator not found: Merge pull request #1890 from samccone/patch-1
#
# ⛲️  Add link to ESTree
# prefix not match: :memo: Add link to ESTree
# separator not found: update escape regex test to use new lodash result
# separator not found: Merge pull request #1884 from arthurvr/resolve
#
# Add `resolve` to `CONTRIBUTING.md`
# prefix not match: Add `resolve` to `CONTRIBUTING.md`
#
# Introduced in https://github.com/babel/babel/commit/aaf4cbf06f48f9f4476ad814ba6f72e064042ff1
# separator not found: Merge pull request #1883 from arthurvr/patch-1
#
# Remove `user-home` from `CONTRIBUTING.md`
# prefix not match: Remove `user-home` from `CONTRIBUTING.md`
#
# In favor of `user-or-tmp`
#
# Ref https://github.com/babel/babel/commit/90b8826e735a01f1f2fc3c300f3bbb40179fd8ee
# separator not found: Merge pull request #1867 from arthurvr/deps
#
# Add `path-exists` to `CONTRIBUTING.md`
# separator not found: fix linting errors
# separator not found: clean up derived classes, fixes super path referencing user constructor instead of our new function - #1877
# separator not found: restructure classes transformer, fix class name inference - #1877
# separator not found: add constructor to body in order that it was supplied in - fixes #1877
# separator not found: move up template literal simplification logic - fixes #1874
# separator not found: remove loose console.log
# separator not found: fix collisions for getBindingIdentifiers
# separator not found: Merge pull request #1868 from benjamn/patch-2
#
# Upgrade Regenerator to 0.8.32.
# prefix not match: Upgrade Regenerator to 0.8.32.
#
# This includes some major runtime performance improvements:
# https://github.com/facebook/regenerator/pull/207
# https://github.com/facebook/regenerator/pull/208
#
# And also some bug fixes relating to async generator functions:
# https://github.com/facebook/regenerator/commit/29d81b6929
# https://github.com/facebook/regenerator/commit/7d2a052ddb
# https://github.com/facebook/regenerator/commit/5b9dd1086d
# separator not found: Add `path-exists` to `CONTRIBUTING.md`
# separator not found: perform function name inference on functions in properties before they're properly visited - fixes #1860
# separator not found: add make comment-issues skeleton
# separator not found: trim eval code in babel-node
# separator not found: add babel-core version to babel-cli version - closes #1861
# separator not found: v5.6.15
# separator not found: v5.6.13
# separator not found: attempt to fix master fetching for automatic travis merge
# separator not found: clean up build website script
# separator not found: output debug current branch/commit info
# separator not found: skip flow types when finding rest parameter references
# separator not found: clean up inType tracking in flow parser plugin
# separator not found: clean up inType tracking in flow parser plugin
# separator not found: add logging for publish cli
# separator not found: try alternate merge parameter
# separator not found: add update-ref master to merge-development-with-master script
# separator not found: Merge branch 'master' into development
# separator not found: +x
# separator not found: wrap TRAVIS_COMMIT variable in curlies for consistency
# separator not found: rebuild website on new version, automatically merge development branch with master - closes #1854, closes #1849
# separator not found: only publish babel-cli when the directory has had changes since the last version - fixes #1848
# separator not found: remove babel-core from babel-cli packag.ejson
# separator not found: fix deprecated return from visitor method api
# separator not found: fix up babel-eslint dependency
# separator not found: v5.6.14
# separator not found: update babel-eslint
# separator not found: update travis with new npm api key
# separator not found: switch to mocha dot reporter
# separator not found: change readme tagline
# separator not found: add test release explanation to changelog
# separator not found: v5.6.13
# separator not found: use npm to publis new version - fixes #1847
# separator not found: clean up readme - add back badges
# separator not found: 5.6.12
# separator not found: v5.6.12
# separator not found: add 5.6.12 changelog
# separator not found: check parent node alongside path in shadow functions
# separator not found: clean up shadow functions findParent logic - fixes #1846
# separator not found: 5.6.11
# separator not found: v5.6.11
# separator not found: make shadowed function findParent target finder more reliable
# separator not found: add missing semi
# separator not found: rejigger shadowd function findParent logic
# separator not found: remove unused variable
# separator not found: add 5.6.11 changelog
# separator not found: merge es6.parameters.rest and es6.parameters.default transformers
#
# This is necessary in order to retain correct function arity and to have
# completely correct semantics. Sometimes features are tied together so much
# that they would require so much desugaring to retain the correct semantics
# that they'd be equivalent to... the normal transpiled output.
# separator not found: upgrade internal dev babel dependency to 5.6.10
# separator not found: 5.6.10
# separator not found: v5.6.10
# separator not found: add use strict
# separator not found: add 5.6.10 changelog
# separator not found: require babel-core at the top of the file
# separator not found: add support for trailing commas in arrow function parameter lists - fixes #1841
# separator not found: add support for trailing commas in arrow function parameter lists - fixes #1841
# separator not found: 5.6.9
# separator not found: v5.6.9
# separator not found: add index.js to fix internal api error
# separator not found: 5.6.8
# separator not found: v5.6.8
# separator not found: fix api module id relative tests
# separator not found: add 5.6.8 changelog
# separator not found: remove root internals protect
# separator not found: don't add protect to register either
# separator not found: don't add protect to polyfill
# separator not found: forgive hotlinking to polyfill
# separator not found: add type import
# separator not found: start linting babel-cli/bin - fixes #1836
# separator not found: use relative tools/protect.js filenames
# separator not found: add path-exists dependency to babel-cli
# prefix not match: Merge branch 'master' of github.com:babel/babel
# separator not found: used filter rather than setting init properties to null in properties.computed transformer - fixes #1831
# separator not found: Merge pull request #1832 from Mark-Simulacrum/path-exists
#
# Use path-exists module instead of fs.exists.
# separator not found: add NodePath#baseTypeStrictlyMatches method
# separator not found: use capitalised builder method
# separator not found: complete t.createTypeAnnotationBasedOnTypeof
# separator not found: add node builder for normal AST node type
# separator not found: force spaces for binary expressions - fixes #1835
# prefix not match: Use path-exists instead of fs.exists.
#
# fs.exists is being deprecated, see: https://github.com/nodejs/io.js/issues/103.
# separator not found: Merge pull request #1821 from kpdecker/destructure-performance
#
# Avoid deopt in iterable destructure template
# separator not found: Merge pull request #1830 from kpdecker/avoid-define-property
#
# Avoid defineProperty when not needed
# separator not found: Avoid defineProperty when not needed
#
# This lets us use the fast path for most object literal assignments and then utilizes the defineProperty path when there is a chance that we could hit the setter issue described in #357.
#
# 10x performance boosts seen for the six-speed test case, going from 200k operations/sec to 2M ops/sec.
# separator not found: Move slice iterator helper out of primary call
#
# Avoids overhead of instantiating the helper on each call to the slice to array helper.
# separator not found: ignore templates folder in protect plugin
# separator not found: don't output comma separator for decorator list and output Property decorators - fixes #1811
# separator not found: Merge branch 'arthurvr-dep'
# prefix not match: Merge branch 'dep' of https://github.com/arthurvr/babel into arthurvr-dep
# separator not found: Merge branch 'arthurvr-tests'
# prefix not match: Merge branch 'tests' of https://github.com/arthurvr/babel into arthurvr-tests
# separator not found: protect internal files from hotlinking
# separator not found: Add tests for `util.resolve`
# separator not found: Remove `leven` dependency
# separator not found: Merge pull request #1822 from azu/patch-1
#
# Add missing asterisk in CHANGELOG
# separator not found: Add missing asterisk in CHANGELOG
# prefix not match: Avoid deopt in iterable destructure template
#
# The try/catch was forcing deoptimization under most engines. This roughly doubles throughput under V8 and 7x increases were seen under Firefox.
#
# Performance numbers based on https://github.com/kpdecker/six-speed/tree/master/tests/destructuring
# separator not found: 5.6.7
# separator not found: v5.6.7
# separator not found: remove test.js
# prefix not match: Merge branch 'master' of github.com:babel/babel
#
# # Conflicts:
# #	src/babel/traversal/path/replacement.js
# separator not found: add 5.6.7 changelog
# separator not found: add missing computed loose test - ref #1820
# separator not found: supress duplicate deprecation messages
# separator not found: always coerce leading computed property initialisers into the init object - fixes #1820
# separator not found: fix block scoping transformer
# separator not found: deprecate returning source strings from visitor methods
# separator not found: deprecate returning source strings from visitor methods
# separator not found: actually push for left declaration to the returned block scoping body - fixes #1819
# separator not found: 5.6.6
# separator not found: v5.6.6
# separator not found: add labels, and inX properties to lookahead getState
# separator not found: add labels, and inX properties to lookahead getState
# separator not found: add inType assignment in flow parse declare method
# separator not found: add inType assignment in flow parse declare method
# separator not found: add 5.6.6 changelog
# separator not found: fixing linting errors
# separator not found: fix isKeyword flow overload
# separator not found: fix isKeyword flow overload
# separator not found: acorn resync
# separator not found: acorn resync
# separator not found: optimise generator for compact mode
# separator not found: parse void as an identifier when inside a type annotation to avoid setting void keyword token - cc @DmitrySoshnikov
# separator not found: parse void as an identifier when inside a type annotation to avoid setting void keyword token - cc @DmitrySoshnikov
# separator not found: upgrade babel-plugin-dead-code-elimination
# separator not found: add 5.6.5 changelog
# separator not found: 5.6.5
# separator not found: v5.6.5
# prefix not match: Merge branch 'master' of github.com:babel/babel
# separator not found: use this.space() instead of manually pushing
# separator not found: clean up t.isReferenced
# separator not found: add Path#couldBeBaseType
# separator not found: fix noOptimise state being incorrect when recursing into multiple nested functions - fixes #1815
# separator not found: Merge pull request #1807 from benjamn/patch-1
#
# Update Regenerator dependency to 0.8.31.
# separator not found: Update Regenerator dependency to 0.8.31.
#
# Fixes #1805.
# separator not found: 5.6.4
# separator not found: v5.6.4
# separator not found: add 5.6.4 changelog
# separator not found: fix Program can only be replaced with another Program error
# separator not found: add ParenthesizedExpression node type for plugins to generate
# separator not found: 5.6.3
# separator not found: v5.6.3
# separator not found: fix rest parameter array allocation loop being incorrectly aliased - fixes #1800
# separator not found: 5.6.2
# separator not found: v5.6.2
# separator not found: remove unused import
# separator not found: log spread element rest parameter as a candidate instead of replacing it in place - fixes #1796
# separator not found: add ensureBlock path method
# separator not found: turn method literal keys into assignments in loose mode - fixes #1797
# separator not found: 5.6.1
# separator not found: v5.6.1
# separator not found: update transformation tests
# separator not found: fix super spread in loose mode
# separator not found: downgrade to babel 5.5.7
# separator not found: 5.6.0
# separator not found: fix build-runtime script
# separator not found: v5.6.0
# separator not found: fix generation tests to reflect acorn update
# separator not found: resync with upstream acorn
# separator not found: resync with upstream acorn
# separator not found: move spec.functionName transformer to builtin-basic - fixes #1743
# separator not found: add noop transform method to IgnoreFormatter
# prefix not match: Merge branch 'master' of github.com:babel/babel
# separator not found: Merge pull request #1776 from zertosh/matches-pattern-this
#
# matchPattern fixes and "this" handling
# separator not found: extend module IgnoreFormatter from DefaultFormatter - fixes #1763, closes #1771
# separator not found: Merge pull request #1772 from arthurvr/booleanify-tests
#
# Add tests for util.booleanify
# separator not found: update babel-plugin-runtime
# separator not found: don't terminate CLI when watching files fail compilation on init - fixes #1678
# separator not found: register labels as bindings - fixes #1747
# separator not found: add uniq to filenames in babel-cli - fixes #1731
# separator not found: split react displayName addition into a plugin - fixes #1761
# separator not found: disable module import receiver when in loose mode - fixes #1788
# separator not found: add more whitespace
# separator not found: check for invalid binding identifiers when generating inferred method names - fixes #1794
# separator not found: remove bluebird
# separator not found: Merge pull request #1793 from lydell/patch-1
#
# Update to js-tokens@1.0.1
# separator not found: Update to js-tokens@1.0.1
# separator not found: Merge pull request #1786 from callumacrae/update-regenerator
#
# Update regenerator
# separator not found: removed ^ from regenerator
# separator not found: update regenerator
# separator not found: add back non-es5 number guard in literal code gen
# separator not found: fix member expression generation on object integers
# separator not found: Add guard against non-ES5 integer literals.
# separator not found: fix up raw number literal
# separator not found: add comments to types generator
# separator not found: clear properties to undefined in traverse.removeProperties

# %%
label_to_commit['🐛 FIX']
# Out:
# ['Images',
#  'Format',
#  'git alias for BREAKING (#31)',
#  'Bangbang Emoji',
#  'Commit msg',
#  'Release scripts',
#  'Lerna',
#  'Release commit',
#  'Remove copy/paste typo in README.md (#13)',
#  'Grammar Lingo',
#  'Readme Typos (#4)',
#  'bad actors',
#  'name',
#  'Lerna commands',
#  'HTML typo',
#  'Badge position',
#  'Formatting',
#  'Center',
#  'Badges code',
#  'Non-flat',
#  'Badges']

# %%
repo.owner.get_repos()
# Out:
# NamedUser(login="ahmadawais")

# %%
from emoji_log_ds.emojiLog import prefixes
prefixes = [p[:-1] for p in prefixes]

# %%
prefixes
# Out:
# ['📦 NEW', '👌 IMPROVE', '🐛 FIX', '📖 DOC', '🚀 RELEASE', '🤖 TEST', '‼️ BREAKING']
